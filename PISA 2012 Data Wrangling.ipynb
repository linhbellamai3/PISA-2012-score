# %%
import pandas as pd
import numpy as np

# %%
pisa12 = pd.read_csv('pisa2012.csv', encoding = "ISO-8859-1")
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pisa12.columns.get_loc('CNT')
# Out:
# 1

# %%
pisa_scores = pisa12.filter(pisa12.columns[1:551], axis=1)

# %%
pisa_scores.columns.get_loc('ST73Q01')
# Out:
# 59

# %%
pisa_scores.columns.get_loc('PV1MATH')
# Out:
# 380

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[1:4], axis =1)

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[2:8], axis =1)

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[4:17], axis =1)

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[5:9], axis =1)

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[7:11], axis =1)

# %%
pisa_scores = pisa_scores.drop(pisa_scores.columns[60:380], axis =1)

# %%
pisa_scores.to_csv('pisa_score.csv')

# %%
pisa_score = pd.read_csv('pisa_score.csv', encoding = "ISO-8859-1")
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,8,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pisa_score
# Out:
#             CNT         NC ST04Q01                                ST13Q01  \
# 0       Albania    Albania  Female                      <ISCED level 3A>
# 1       Albania    Albania  Female                      <ISCED level 3A>
# 2       Albania    Albania  Female                  <ISCED level 3B, 3C>
# 3       Albania    Albania  Female                  <ISCED level 3B, 3C>
# 4       Albania    Albania  Female  She did not complete <ISCED level 1>
# 5       Albania    Albania  Female                  <ISCED level 3B, 3C>
# 6       Albania    Albania  Female                  <ISCED level 3B, 3C>
# 7       Albania    Albania    Male                      <ISCED level 3A>
# 8       Albania    Albania  Female                      <ISCED level 3A>
# 9       Albania    Albania  Female                      <ISCED level 3A>
# 10      Albania    Albania  Female                      <ISCED level 3A>
# 11      Albania    Albania  Female                      <ISCED level 3A>
# ...

# %%
pisa_score = pisa_score.drop(['Unnamed: 0'], axis =1)

# %%
ISCED_level_6 = pisa_score[pisa_score['ST14Q01'] == 'Yes']
ISCED_level_5A = pisa_score[(pisa_score['ST14Q01'] == 'No') & (pisa_score['ST14Q02'] == 'Yes')]
ISCED_level_5B = pisa_score[(pisa_score['ST14Q01'] == 'No') & (pisa_score['ST14Q02'] == 'No')&(pisa_score['ST14Q03'] == 'Yes')]
ISCED_level_4 = pisa_score[(pisa_score['ST14Q01'] == 'No') & (pisa_score['ST14Q02'] == 'No')&(pisa_score['ST14Q03'] == 'No')&(pisa_score['ST14Q04'] == 'Yes')]

# %%
indexes_level6 = ISCED_level_6.index.tolist()
for i in indexes_level6:
    pisa_score['ST13Q01'][i] = '<ISCED level 6>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level5A = ISCED_level_5A.index.tolist()
for i in indexes_level5A:
    pisa_score['ST13Q01'][i] = '<ISCED level 5A>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level5B = ISCED_level_5B.index.tolist()
for i in indexes_level5B:
    pisa_score['ST13Q01'][i] = '<ISCED level 5B>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level4 = ISCED_level_4.index.tolist()
for i in indexes_level4:
    pisa_score['ST13Q01'][i] = '<ISCED level 4>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ISCED_level_6 = pisa_score[pisa_score['ST18Q01'] == 'Yes']
ISCED_level_5A = pisa_score[(pisa_score['ST18Q01'] == 'No') & (pisa_score['ST18Q02'] == 'Yes')]
ISCED_level_5B = pisa_score[(pisa_score['ST18Q01'] == 'No') & (pisa_score['ST18Q02'] == 'No')&(pisa_score['ST18Q03'] == 'Yes')]
ISCED_level_4 = pisa_score[(pisa_score['ST18Q01'] == 'No') & (pisa_score['ST18Q02'] == 'No')&(pisa_score['ST18Q03'] == 'No')&(pisa_score['ST18Q04'] == 'Yes')]

# %%
indexes_level6 = ISCED_level_6.index.tolist()
for i in indexes_level6:
    pisa_score['ST17Q01'][i] = '<ISCED level 6>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level5A = ISCED_level_5A.index.tolist()
for i in indexes_level5A:
    pisa_score['ST17Q01'][i] = '<ISCED level 5A>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level5B = ISCED_level_5B.index.tolist()
for i in indexes_level5B:
    pisa_score['ST17Q01'][i] = '<ISCED level 5B>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
indexes_level4 = ISCED_level_4.index.tolist()
for i in indexes_level4:
    pisa_score['ST17Q01'][i] = '<ISCED level 4>'
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pisa_score = pisa_score.drop(['ST14Q01', 'ST14Q02', 'ST14Q03', 'ST14Q04', 'ST18Q01', 'ST18Q02', 'ST18Q03', 'ST18Q04'], axis =1)

# %%
pisa_score.to_csv('pisa12.csv')
